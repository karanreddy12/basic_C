# %% [markdown]
# <a href="https://colab.research.google.com/github/karanreddy12/basic_C/blob/main/yolov5_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.7/802.7 kB 9.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# prompt: how to save the all the files runed in colab in drive

from google.colab import drive
drive.mount('/content/drive')

# Assuming you want to save files in a folder named 'colab_output' in your Drive
# !cp -r /content/* /content/drive/MyDrive/colab_output
# Out:
# Mounted at /content/drive
# cp: target '/content/drive/MyDrive/colab_output' is not a directory

# %%
# prompt: curl -L "https://app.roboflow.com/ds/VlMQTYNvIu?key=cE27xTkdCM" &gt; roboflow.zip; unzip roboflow.zip; rm roboflow.zip

from google.colab import drive
# !pip install ultralytics

drive.mount('/content/drive')

# Assuming you want to save files in a folder named 'colab_output' in your Drive
# !cp -r /content/* /content/drive/MyDrive/colab_output

# !curl -L "https://app.roboflow.com/ds/VlMQTYNvIu?key=cE27xTkdCM" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/IMG20240520102900_jpg.rf.71150f1f3b1971cd0585b2ecc6fa3fcb.jpg
#  extracting: train/images/IMG20240520102900_jpg.rf.95bb268988e19ca4af890ef7dd0a058e.jpg
#  extracting: train/images/IMG20240520102900_jpg.rf.96b22b2ed6b97ffab96a0378d05f7208.jpg
#  extracting: train/images/IMG20240520102905_jpg.rf.21d84edb80b5e65cfc533d00f8e3a392.jpg
#  extracting: train/images/IMG20240520102905_jpg.rf.46b4f2b184822e04b81f575100ad7850.jpg
#  extracting: train/images/IMG20240520102905_jpg.rf.af7574d1c67827ed97a5dcec6db9b34a.jpg
#  extracting: train/images/IMG20240520102913_jpg.rf.10f11ffa0bf03083c9763f27ba5e264c.jpg
#  extracting: train/images/IMG20240520102913_jpg.rf.375976fafbc4204b506f476c1a4ed134.jpg
#  extracting: train/images/IMG20240520102913_jpg.rf.f5a176a0a189e15baea6e8bf84be876a.jpg
#  extracting: train/images/IMG20240520102923_jpg.rf.7bf2e79fe8e925ed9dd3b76b0f7fe462.jpg
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv5n model
model = YOLO("yolov5n.pt")

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="/content/data.yaml", epochs=100,batch=50,imgsz=640)
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 134MB/s]
# YOLOv5n summary: 262 layers, 2,654,816 parameters, 0 gradients, 7.8 GFLOPs
# Ultralytics YOLOv8.2.58 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Run inference on 'bus.jpg' with arguments
model.predict("/content/te", save=True, imgsz=640, conf=0.5)
# Out:
# image 1/7 /content/te/test1.jpg: 320x640 2 Buss, 1 auto, 1 car, 126.3ms
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# image 2/7 /content/te/test2.jpg: 320x640 1 Bike, 2 Buss, 7.7ms
# image 3/7 /content/te/test3.jpg: 320x640 1 Bike, 1 Truck, 7.0ms
# image 4/7 /content/te/test4.jpg: 320x640 (no detections), 6.9ms
# image 5/7 /content/te/test5.jpg: 640x320 3 Barrior_Cones, 1 auto, 76.6ms
# image 6/7 /content/te/test6.jpg: 320x640 1 Bus, 1 Truck, 7.6ms
# image 7/7 /content/te/test7.jpg: 640x384 1 car, 1 pedestrian, 65.9ms
# Speed: 1.9ms preprocess, 42.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# ...
